# %%
import pandas as pd
df = pd.read_csv("data.csv")

# %%
df.head()
# Out:
#                    Product                                             Review
# 0     Queen Size Sheet Set  I ordered a king size set. My only criticism w...
# 1   Waterproof Phone Pouch  I loved the waterproof sac, although the openi...
# 2      Luxury Air Mattress  This mattress had a small hole in the top of i...
# 3           Pillows Insert  This is the best throw pillow fillers on Amazo...
# 4  Milk Frother Handheld\n   I loved this product. But they only seem to l...

# %% [markdown]
# ## LLMChain

# %%
from langchain_ollama import ChatOllama
from langchain_core.prompts import ChatPromptTemplate
from langchain_classic.chains import LLMChain

# %%
llm = ChatOllama(temperature=0.9, model="gemma3:4b")

# %%
prompt = ChatPromptTemplate.from_template(
    "What is the best name to describe \
    a company that makes {product}?"
)

# %%
chain = LLMChain(llm=llm, prompt=prompt)

# %%
product = "Queem Size Sheet Set"
chain.run(product)
# Out:
# 'Okay, let\'s brainstorm some names for a company making Queen Size Sheet Sets! Here\'s a breakdown of ideas, categorized by feel, with explanations of why they might work:\n\n**1. Luxurious & Elegant:**\n\n* **Royal Slumber:** Evokes royalty and a feeling of premium sleep.\n* **The Queen\'s Comfort:** Directly references the size and emphasizes comfort.\n* **Velvet Crown Sheets:** “Velvet” suggests luxury, and “Crown” links to royalty.\n* **Seraphina Sheets:** “Seraphina” has a beautiful, ethereal feel, suggesting softness and quality.\n* **Elysian Linens:** "Elysian" refers to paradise, associating the sheets with a blissful experience.\n\n\n\n**2. Simple & Direct:**\n\n* **Queen Size Sheets Co.:** Clear, concise, and immediately tells you what you’re selling.\n* **Queen Comfort Sheets:**  Simple and focuses on the benefit.\n* **The Queen Set:** Short, memorable, and gets right to the point.\n\n\n\n**3. Modern & Stylish:**\n\n* **Luxe Sleep Co.:** "Luxe" is a popular term for luxury, and "Co." feels contemporary.\n* **Slate & Silk:** Combines a neutral color with a luxurious fabric.\n* **The Restful Edit:** "Edit" suggests curated quality and a modern aesthetic.\n\n\n\n**4. Creative & Playful:**\n\n* **Dream Weaver Sheets:**  A bit whimsical and suggests a good night\'s sleep.\n* **Slumber Haven:**  Creates a feeling of safety and relaxation.\n* **The Cozy Kingdom:**  Fun, memorable, and appeals to a sense of comfort.\n\n\n\n**Tips for Choosing & Checking Availability:**\n\n* **Check Domain Availability:**  Before you fall in love with a name, see if the .com domain is available.  This is *crucial*.\n* **Check Social Media Handles:**  Make sure the name isn\'t already taken on Instagram, Facebook, etc.\n* **Say it Out Loud:**  Make sure it\'s easy to pronounce and remember.\n* **Consider Your Brand Identity:**  What’s the overall feel you\'re going for? (e.g., minimalist, bohemian, traditional, modern)\n\n\n**My Top Recommendations (Based on overall appeal):**\n\n* **Royal Slumber:** Strong, evocative, and luxurious.\n* **Queen Comfort Sheets:** Clear, direct, and easy to understand.\n* **Luxe Sleep Co.:** Modern, stylish, and appealing to a broad audience.\n\nTo help me narrow it down and give you even more targeted suggestions, could you tell me:\n\n*   **What is the overall style of the sheets?** (e.g., Egyptian cotton, percale, sateen, linen, patterned, solid colors?)\n*   **What is the price point?** (e.g., budget-friendly, mid-range, luxury?)'

# %% [markdown]
# ## SequentialChains

# %%
from langchain_classic.chains import SequentialChain

# %%
#
